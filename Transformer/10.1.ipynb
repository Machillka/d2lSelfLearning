# %%
import seaborn as sns
import numpy as np
import torch
import torch.nn.functional as F
from torch import rand, tensor, Tensor, nn

# %matplotlib inline

sns.set_theme(style="white")

# %%
data = F.softmax(rand(10, 10), dim = 1)
sns.heatmap(data, cmap="crest")
# Out:
# <Axes: >
